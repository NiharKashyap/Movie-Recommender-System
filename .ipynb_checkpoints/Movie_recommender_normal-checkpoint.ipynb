# %%
import pandas as pd
import numpy as np
import os
from ast import literal_eval
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('Downloads//archive//movies_metadata.csv')
# Out:
# C:\Users\Nihar\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1        Jumanji  When siblings Judy and Peter discover an encha...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                      tagline      title  video vote_average  \
# 0                                        NaN  Toy Story  False          7.7
# 1  Roll the dice and unleash the excitement!    Jumanji  False          6.9
#
#   vote_count
# 0     5415.0
# 1     2413.0
#
# [2 rows x 24 columns]

# %%
df.fillna('', inplace=True)

# %%
columns_needed = ['genres', 'title', 'overview', 'tagline']
df_modified = df[columns_needed]
df_modified
# Out:
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45461                       Subdue
# 45462          Century of Birthing
# 45463                     Betrayal
# 45464             Satan Triumphant
# 45465                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 45461        Rising and falling between a man and woman.
# 45462  An artist struggles to finish his work while a...
# 45463  When one of her hits goes wrong, a professiona...
# 45464  In a small town live two brothers, one a minis...
# 45465  50 years after decriminalisation of homosexual...
#
#                                                  tagline
# 0
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462
# 45463                             A deadly game of wits.
# 45464
# 45465
#
# [45466 rows x 4 columns]

# %%
df_modified['genres'] = df_modified['genres'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
# Out:
# C:\Users\Nihar\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_modified['belongs_to_collection'][0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
df_modified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genres    45466 non-null  object
#  1   title     45466 non-null  object
#  2   overview  45466 non-null  object
#  3   tagline   45466 non-null  object
# dtypes: object(4)
# memory usage: 1.4+ MB

# %%
def combine_genres(col):
    genres = ''
    for i in range(len(col)):
        genres = genres + ' ' + col[i]
    return genres

# %%
df_modified['combined_genres'] = df_modified['genres'].apply(combine_genres)
# Out:
# C:\Users\Nihar\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_modified.drop('genres', axis=1, inplace=True)
# Out:
# C:\Users\Nihar\Anaconda3\lib\site-packages\pandas\core\frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_modified
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45461                       Subdue
# 45462          Century of Birthing
# 45463                     Betrayal
# 45464             Satan Triumphant
# 45465                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 45461        Rising and falling between a man and woman.
# 45462  An artist struggles to finish his work while a...
# 45463  When one of her hits goes wrong, a professiona...
# 45464  In a small town live two brothers, one a minis...
# 45465  50 years after decriminalisation of homosexual...
#
#                                                  tagline  \
# 0
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462
# 45463                             A deadly game of wits.
# 45464
# 45465
#
#                  combined_genres
# 0        Animation Comedy Family
# 1       Adventure Fantasy Family
# 2                 Romance Comedy
# 3           Comedy Drama Romance
# 4                         Comedy
# ...                          ...
# 45461               Drama Family
# 45462                      Drama
# 45463      Action Drama Thriller
# 45464
# 45465
#
# [45466 rows x 4 columns]

# %%
df_final = df_modified.copy()

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            45466 non-null  object
#  1   overview         45466 non-null  object
#  2   tagline          45466 non-null  object
#  3   combined_genres  45466 non-null  object
# dtypes: object(4)
# memory usage: 1.4+ MB

# %%
def combine_frames(row):
    comb=''
    comb = row['title'] + ' ' + row['overview'] + ' ' + row['tagline'] + ' ' + row['combined_genres']
    df_final['combined_data'] = comb

# %%
combine_frames(df_final)
#df_modified['combined_data'] = df_modified.apply(combine_frames)

# %%
df_final
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45461                       Subdue
# 45462          Century of Birthing
# 45463                     Betrayal
# 45464             Satan Triumphant
# 45465                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 45461        Rising and falling between a man and woman.
# 45462  An artist struggles to finish his work while a...
# 45463  When one of her hits goes wrong, a professiona...
# 45464  In a small town live two brothers, one a minis...
# 45465  50 years after decriminalisation of homosexual...
#
#                                                  tagline  \
# 0
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462
# 45463                             A deadly game of wits.
# 45464
# 45465
#
#                  combined_genres  \
# 0        Animation Comedy Family
# 1       Adventure Fantasy Family
# 2                 Romance Comedy
# 3           Comedy Drama Romance
# 4                         Comedy
# ...                          ...
# 45461               Drama Family
# 45462                      Drama
# 45463      Action Drama Thriller
# 45464
# 45465
#
#                                            combined_data
# 0      Toy Story Led by Woody, Andy's toys live happi...
# 1      Jumanji When siblings Judy and Peter discover ...
# 2      Grumpier Old Men A family wedding reignites th...
# 3      Waiting to Exhale Cheated on, mistreated and s...
# 4      Father of the Bride Part II Just when George B...
# ...                                                  ...
# 45461  Subdue Rising and falling between a man and wo...
# 45462  Century of Birthing An artist struggles to fin...
# 45463  Betrayal When one of her hits goes wrong, a pr...
# 45464  Satan Triumphant In a small town live two brot...
# 45465  Queerama 50 years after decriminalisation of h...
#
# [45466 rows x 5 columns]

# %%
df_part1 = df_final[:11366]
df_part1
# Out:
#                                     title  \
# 0                               Toy Story
# 1                                 Jumanji
# 2                        Grumpier Old Men
# 3                       Waiting to Exhale
# 4             Father of the Bride Part II
# ...                                   ...
# 11361                               Spies
# 11362  A Guide To Recognizing Your Saints
# 11363              Azumi 2: Death or Love
# 11364                          13 Tzameti
# 11365                             Saw III
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 11361  The mastermind behind a ubiquitous spy operati...
# 11362  Dito Montiel, a successful author, receives a ...
# 11363  Young assassins Azumi and Nagara continue thei...
# 11364  Sebastian, a young man, has decided to follow ...
# 11365  Jigsaw has disappeared. Along with his new app...
#
#                                                  tagline  \
# 0
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 11361
# 11362  Sometimes the only way to move forward is to g...
# 11363            Love Or Duty... An Assassin Must Choose
# 11364
# 11365        Suffering? You Haven't Seen Anything Yet...
#
#                  combined_genres  \
# 0        Animation Comedy Family
# 1       Adventure Fantasy Family
# 2                 Romance Comedy
# 3           Comedy Drama Romance
# 4                         Comedy
# ...                          ...
# 11361      Action Drama Thriller
# 11362                Crime Drama
# 11363                     Action
# 11364            Action Thriller
# 11365      Horror Thriller Crime
#
#                                            combined_data
# 0      Toy Story Led by Woody, Andy's toys live happi...
# 1      Jumanji When siblings Judy and Peter discover ...
# 2      Grumpier Old Men A family wedding reignites th...
# 3      Waiting to Exhale Cheated on, mistreated and s...
# 4      Father of the Bride Part II Just when George B...
# ...                                                  ...
# 11361  Spies The mastermind behind a ubiquitous spy o...
# 11362  A Guide To Recognizing Your Saints Dito Montie...
# 11363  Azumi 2: Death or Love Young assassins Azumi a...
# 11364  13 Tzameti Sebastian, a young man, has decided...
# 11365  Saw III Jigsaw has disappeared. Along with his...
#
# [11366 rows x 5 columns]

# %%
df_part2 = df_final[11366:22732]
df_part2
# Out:
#                            title  \
# 11366               Catch a Fire
# 11367       Death of a President
# 11368             Little Secrets
# 11369        The Kaiser's Lackey
# 11370   Corto Maltese in Siberia
# ...                          ...
# 22727                      Crave
# 22728                   Betrayed
# 22729  Between Midnight and Dawn
# 22730      Nymphomaniac: Vol. II
# 22731                    La luna
#
#                                                 overview  \
# 11366  The true story of anti-apartheid activists in ...
# 11367  A fictional investigative documentary looks ba...
# 11368  Emily Lindstrom, 14, is an aspiring concert vi...
# 11369  Diederich Heßling is scared of everything and ...
# 11370  At the end of 1918 while civil war is raging o...
# ...                                                  ...
# 22727  Aiden (Josh Lawson) craves a better life. A li...
# 22728  Screen superstars Clark Gable ("Gone With The ...
# 22729  Rocky and Dan, war buddies, are prowl car cops...
# 22730  The continuation of Joe's sexually dictated li...
# 22731  A young boy comes of age in the most peculiar ...
#
#                                                  tagline  \
# 11366              The spark that ignites us, unites us.
# 11367
# 11368
# 11369
# 11370
# ...                                                  ...
# 22727        His imagination is a dangerous place to be.
# 22728   M-G-M filmed the mystery of the year in Holland!
# 22729  THE STORY OF PROWL CAR 13...BASED ON THE POLIC...
# 22730                                  Forget About Love
# 22731  A young boy discovers his family's most unusua...
#
#                           combined_genres  \
# 11366               Action Drama Thriller
# 11367   Documentary Drama Science Fiction
# 11368                        Drama Family
# 11369                History Drama Comedy
# 11370   Drama Animation History Adventure
# ...                                   ...
# 22727                      Drama Thriller
# 22728          Drama Romance Thriller War
# 22729                         Crime Drama
# 22730                       Drama Mystery
# 22731                    Animation Family
#
#                                            combined_data
# 11366  Catch a Fire The true story of anti-apartheid ...
# 11367  Death of a President A fictional investigative...
# 11368  Little Secrets Emily Lindstrom, 14, is an aspi...
# 11369  The Kaiser's Lackey Diederich Heßling is scare...
# 11370  Corto Maltese in Siberia At the end of 1918 wh...
# ...                                                  ...
# 22727  Crave Aiden (Josh Lawson) craves a better life...
# 22728  Betrayed Screen superstars Clark Gable ("Gone ...
# 22729  Between Midnight and Dawn Rocky and Dan, war b...
# 22730  Nymphomaniac: Vol. II The continuation of Joe'...
# 22731  La luna A young boy comes of age in the most p...
#
# [11366 rows x 5 columns]

# %%
df_part3 = df_final[22732:34098]
df_part3
# Out:
#                           title  \
# 22732        A Place in the Sun
# 22733  A Streetcar Named Desire
# 22734  A Streetcar Named Desire
# 22735           American Anthem
# 22736                Between Us
# ...                         ...
# 34093     Four Times That Night
# 34094     The House of Exorcism
# 34095     Knives of the Avenger
# 34096    Gunman Called Nebraska
# 34097    The Road to Fort Alamo
#
#                                                 overview  \
# 22732  A Swedish family found murdered in her home on...
# 22733  Blanche Dubois goes to visit her pregnant sist...
# 22734  Blanche Dubois goes to visit her pregnant sist...
# 22735  Steve is a talented gymnast who has given up c...
# 22736  A New York couple and their Midwestern friends...
# ...                                                  ...
# 34093  John and Tina meet in a park one day. They imm...
# 34094  A total re-edit of Mario Bava's gothic classic...
# 34095  A mysterious knife-throwing viking warrior pro...
# 34096  A drifter helps a ranch couple fend off the ap...
# 34097  A lone rider comes across a dying soldier, the...
#
#                                                  tagline  \
# 22732
# 22733
# 22734
# 22735
# 22736  Four Friends. Two Couples. One Night They Will...
# ...                                                  ...
# 34093
# 34094
# 34095
# 34096
# 34097
#
#              combined_genres  \
# 22732   Crime Drama Thriller
# 22733
# 22734
# 22735                Romance
# 22736                  Drama
# ...                      ...
# 34093                 Comedy
# 34094                 Horror
# 34095       Action Adventure
# 34096                Western
# 34097                Western
#
#                                            combined_data
# 22732  A Place in the Sun A Swedish family found murd...
# 22733  A Streetcar Named Desire Blanche Dubois goes t...
# 22734  A Streetcar Named Desire Blanche Dubois goes t...
# 22735  American Anthem Steve is a talented gymnast wh...
# 22736  Between Us A New York couple and their Midwest...
# ...                                                  ...
# 34093  Four Times That Night John and Tina meet in a ...
# 34094  The House of Exorcism A total re-edit of Mario...
# 34095  Knives of the Avenger A mysterious knife-throw...
# 34096  Gunman Called Nebraska A drifter helps a ranch...
# 34097  The Road to Fort Alamo A lone rider comes acro...
#
# [11366 rows x 5 columns]

# %%
df_part4 = df_final[34098:45464]
df_part4
# Out:
#                      title                                           overview  \
# 34098  One Night at Dinner  A liberal-thinking author watches his wife as ...
# 34099               Trumbo  The career of screenwriter Dalton Trumbo is ha...
# 34100         Panic Button  A businessman comes up with a scheme to make m...
# 34101    Two Sons of Ringo
# 34102   The Moment to Kill  Two famous gunmen, Lord and Bull are called to...
# ...                    ...                                                ...
# 45459      Caged Heat 3000  It's the year 3000 AD. The world's most danger...
# 45460           Robin Hood  Yet another version of the classic epic, with ...
# 45461               Subdue        Rising and falling between a man and woman.
# 45462  Century of Birthing  An artist struggles to finish his work while a...
# 45463             Betrayal  When one of her hits goes wrong, a professiona...
#
#                                           tagline         combined_genres  \
# 34098                                                               Drama
# 34099        Are you now or have you ever been...                   Drama
# 34100                                                              Comedy
# 34101                                                              Comedy
# 34102                                                             Western
# ...                                           ...                     ...
# 45459                                                     Science Fiction
# 45460                                                Drama Action Romance
# 45461  Rising and falling between a man and woman            Drama Family
# 45462                                                               Drama
# 45463                      A deadly game of wits.   Action Drama Thriller
#
#                                            combined_data
# 34098  One Night at Dinner A liberal-thinking author ...
# 34099  Trumbo The career of screenwriter Dalton Trumb...
# 34100  Panic Button A businessman comes up with a sch...
# 34101                        Two Sons of Ringo    Comedy
# 34102  The Moment to Kill Two famous gunmen, Lord and...
# ...                                                  ...
# 45459  Caged Heat 3000 It's the year 3000 AD. The wor...
# 45460  Robin Hood Yet another version of the classic ...
# 45461  Subdue Rising and falling between a man and wo...
# 45462  Century of Birthing An artist struggles to fin...
# 45463  Betrayal When one of her hits goes wrong, a pr...
#
# [11366 rows x 5 columns]

# %%
cv = CountVectorizer()

count_matrix1 = cv.fit_transform(df_part1["combined_data"])
count_matrix2 = cv.fit_transform(df_part2["combined_data"])
count_matrix3 = cv.fit_transform(df_part3["combined_data"])
count_matrix4 = cv.fit_transform(df_part4["combined_data"])

# %% [markdown]
# The next Cell used tfid instead of count vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(ngram_range=(1, 1), min_df=0.0001, stop_words='english')

count_matrix1 = tfidf.fit_transform(df_part1["combined_data"])
count_matrix2 = tfidf.fit_transform(df_part2["combined_data"])
count_matrix3 = tfidf.fit_transform(df_part3["combined_data"])
count_matrix4 = tfidf.fit_transform(df_part4["combined_data"])

# %%
cosine_sim1 = cosine_similarity(count_matrix1)
cosine_sim2 = cosine_similarity(count_matrix2)
cosine_sim3 = cosine_similarity(count_matrix3)
cosine_sim4 = cosine_similarity(count_matrix4)

# %%
combined = np.vstack([cosine_sim1, cosine_sim2, cosine_sim3, cosine_sim4])

# %%
def get_title_from_index(index):
    return df_final[df_final.index==index]['title'].values[0]
def get_index_from_title(title):
    return df_final[df_final.title==title].index[0]

# %%
movie_user_likes = "Saw III"

# %%
movie_index = get_index_from_title(movie_user_likes)
movie_index
# Out:
# 11365

# %%
similar_movies = list(enumerate(combined[movie_index]))

# %%
sorted_similar_movies = sorted(similar_movies, key = lambda x:x[1], reverse = True)[1:]

# %%
i=0
print("Top 5 similar movies to "+movie_user_likes+" are:\n")
for element in sorted_similar_movies:
    print(get_title_from_index(element[0]))
    i=i+1
    if i>10:
        break
# Out:
# Top 5 similar movies to Saw III are:
#
# Saw II
# Curse of the Puppet Master
# Retro Puppet Master
# Puppet Master 5: The Final Chapter
# Puppet Master II
# The Vanishing
# White Lightning
# Puppet Master
# Breakdown
# The Detective
# Watermelon Man

# %%
df_final[df_final.index==1773]
# Out:
#          title                                           overview  \
# 1773  Godzilla  When a freighter is viciously attacked in the ...
#
#                 tagline                   combined_genres  \
# 1773  Size does matter.   Science Fiction Action Thriller
#
#                                           combined_data
# 1773  Godzilla When a freighter is viciously attacke...

# %%
df_final[df_final.title=="Two Evil Eyes"]
# Out:
#               title                                           overview  \
# 6259  Two Evil Eyes  Two horror segments based on Edgar Allan Poe s...
#
#                                 tagline   combined_genres  \
# 6259  When I wake you... you'll be dead   Horror Thriller
#
#                                           combined_data
# 6259  Two Evil Eyes Two horror segments based on Edg...

# %%
np.save('Cosine_matrix.csv', combined)
